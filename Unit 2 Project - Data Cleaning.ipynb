# %% [markdown]
# # Unit 2 Project - Data Cleaning

# %% [markdown]
# ## Part 1: Prepare Environment and Jupyter Notebook

# %% [markdown]
# ### Step 1: Create Virtual Environment
#
# This step should have been completed prior to opening the Jupyter Notebook. Refer to project instructions.

# %% [markdown]
# ### Step 2: Open Jupyter Notebook File
#
# Congratulations! If you're here it means you have completed Step 2.

# %% [markdown]
# ### Step 3: Load .csv Files into DataFrames

# %%
import pandas as pd

# %%
####### TO DO ########

# load house_data.csv into a dataframe using pd.read_csv()

raw_house_df = pd.read_csv('house_data.csv')

# load house_sales.csv into a dataframe using pd.read_csv()

raw_sales_df = pd.read_csv('house_sales.csv')

######################

# %%
###### TO DO ######

# use .head() on your new dataframe to show the dataframe was loaded succussfully

raw_house_df.head()
# Out:
#    Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0           0  7129300520         3       1.00         1180    5650.0     1.0
# 1           1  6414100192         3       2.25         2570    7242.0     2.0
# 2           2  5631500400         2       1.00          770   10000.0     1.0
# 3           3  2487200875         4       3.00         1960    5000.0     1.0
# 4           4  1954400510         3       2.00         1680    8080.0     1.0
#
#   Waterfront?       View  House Condition  Grade  SQFT above  SQFT basement  \
# 0          No  Very Poor     OK Condition    7.0      1180.0              0
# 1          No  Very Poor     OK Condition    7.0      2170.0            400
# 2          No  Very Poor     OK Condition    6.0       770.0              0
# 3          No  Very Poor  Great Condition    7.0      1050.0            910
# 4          No  Very Poor     OK Condition    8.0      1680.0              0
#
# ...

# %%
###### TO DO ######

# use .head() on your second new dataframe to show the dataframe was loaded succussfully

raw_sales_df.head()
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %%
# check the info othe two dataframes.

raw_house_df.info()
    
raw_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       21613 non-null  int64
#  1   ID               21613 non-null  int64
#  2   Bedrooms         21613 non-null  int64
#  3   Bathrooms        21611 non-null  float64
#  4   SQFT living      21613 non-null  int64
#  5   SQFT lot         21611 non-null  float64
#  6   Floors           21613 non-null  float64
#  7   Waterfront?      21605 non-null  object
#  8   View             21611 non-null  object
#  9   House Condition  21607 non-null  object
#  10  Grade            21611 non-null  float64
#  11  SQFT above       21612 non-null  float64
#  12  SQFT basement    21613 non-null  int64
#  13  Year Built       21612 non-null  float64
#  14  Year Renovated   21276 non-null  float64
#  15  Zipcode          21610 non-null  float64
# ...

# %% [markdown]
# ### Step 4: Create Data Dictionaries for Each Dataset

# %%
####### TO DO ###########

# Work in the cells below to fill in missing information in the data dictionary.

# %% [markdown]
# #### Data Dictionary - House Data
#
# **id**:
# > Description:House id.
# >
# > Data type: int
#
# **bedrooms**:
# > Description: Number of bedrooms
# >
# > Data type:int
#
# **bathrooms**:
# > Description:Number of bathrooms
# >
# > Data type:float
#
# **sqft_living**:
# > Description:square foot of the living space
# >
# > Data type:int
#
# **sqft_lot**:
# > Description:squarefooteage of the lot
# >
# > Data type: float
#
# **floors**:
# > Description:Number of floors in the house.
# >
# > Data type: float
#
# **waterfront**:
# > Description: whether there is waterfornt for the house.
# >
# > Data type:object
#
# **view**:
# > Description:does the house have view.
#
# >
# > Data type:object
#
# **condition**:
# > Description: condition of the house
# >
# > Data type: object
#
# **grade**:
# > Description: grade of the construction.
#
# >
# > Data type: float
#
# **sqft_above**:
# > Description: square footage of the space abouve the houise
# >
# > Data type:float
#
# **sqft_basement**:
# > Description: squarefootage of the basement
# >
# > Data type: int
#
# **yr_built**:
# > Description:the year the house is built in
# >
# > Data type: float
#
# **yr_renovated**:
# > Description:the year renovated the house.
#
# >
# > Data type: float
#
# **zipcode**:
# > Description: zipcode of the house
# >
# > Data type: float
#
# **lat**:
# > Description: latitude of the house
# >
# > Data type: float
#
# **long**:
# > Description:Longitude of the house
# >
# > Data type: float
#
# **sqft_living15**:
# > Description: square footage of the 15 nearby houses
# >
# > Data type: int
#
# **sqft_lot15**:
# > Description: square footage of the 15 nearby lots
# >
# > Data type: int

# %% [markdown]
# #### Data Dictionary - House Sales Data
#
# **id**:
# > Description: sale id
# >
# > Data type:int
#
# **date**:
# > Description: date the sale happend
# >
# > Data type:object
#
# **price**:
# > Description:price of the house
# >
# > Data type: object

# %% [markdown]
# ### Step 5: Create Copies of DataFrames to Start Cleaning Process

# %%
###### TO DO ######

# create a copy of house_data

house_df = raw_house_df.copy()


# create a copy of sales_data

sales_df = raw_sales_df.copy()

# %%
###### TO DO ######

# use .head() on your new dataframe to show the dataframe was copied succussfully
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       21613 non-null  int64
#  1   ID               21613 non-null  int64
#  2   Bedrooms         21613 non-null  int64
#  3   Bathrooms        21611 non-null  float64
#  4   SQFT living      21613 non-null  int64
#  5   SQFT lot         21611 non-null  float64
#  6   Floors           21613 non-null  float64
#  7   Waterfront?      21605 non-null  object
#  8   View             21611 non-null  object
#  9   House Condition  21607 non-null  object
#  10  Grade            21611 non-null  float64
#  11  SQFT above       21612 non-null  float64
#  12  SQFT basement    21613 non-null  int64
#  13  Year Built       21612 non-null  float64
#  14  Year Renovated   21276 non-null  float64
#  15  Zipcode          21610 non-null  float64
# ...

# %%
###### TO DO ######

# use .head() on your second new dataframe to show the dataframe was copied succussfully

sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21613 non-null  int64
#  1   Id          21613 non-null  int64
#  2   DATE        21613 non-null  object
#  3   Price       21609 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 675.5+ KB

# %% [markdown]
# ## Part 2: Assess Data and Create Data Cleaning Plan

# %% [markdown]
# ### Step 1: Check Column Names, Casing, Spelling, Etc.

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       21613 non-null  int64
#  1   ID               21613 non-null  int64
#  2   Bedrooms         21613 non-null  int64
#  3   Bathrooms        21611 non-null  float64
#  4   SQFT living      21613 non-null  int64
#  5   SQFT lot         21611 non-null  float64
#  6   Floors           21613 non-null  float64
#  7   Waterfront?      21605 non-null  object
#  8   View             21611 non-null  object
#  9   House Condition  21607 non-null  object
#  10  Grade            21611 non-null  float64
#  11  SQFT above       21612 non-null  float64
#  12  SQFT basement    21613 non-null  int64
#  13  Year Built       21612 non-null  float64
#  14  Year Renovated   21276 non-null  float64
#  15  Zipcode          21610 non-null  float64
# ...

# %%
house_df.head()
# Out:
#    Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0           0  7129300520         3       1.00         1180    5650.0     1.0
# 1           1  6414100192         3       2.25         2570    7242.0     2.0
# 2           2  5631500400         2       1.00          770   10000.0     1.0
# 3           3  2487200875         4       3.00         1960    5000.0     1.0
# 4           4  1954400510         3       2.00         1680    8080.0     1.0
#
#   Waterfront?       View  House Condition  Grade  SQFT above  SQFT basement  \
# 0          No  Very Poor     OK Condition    7.0      1180.0              0
# 1          No  Very Poor     OK Condition    7.0      2170.0            400
# 2          No  Very Poor     OK Condition    6.0       770.0              0
# 3          No  Very Poor  Great Condition    7.0      1050.0            910
# 4          No  Very Poor     OK Condition    8.0      1680.0              0
#
# ...

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21613 non-null  int64
#  1   Id          21613 non-null  int64
#  2   DATE        21613 non-null  object
#  3   Price       21609 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 675.5+ KB

# %%
sales_df.head()
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %% [markdown]
# ### Step 2: Validate Data Types

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Q: Do any of the data types in the dataframe need to be changed?

# %% [markdown]
# A: #### TO DO #####
#
# house data:
#
# ID : int -->str
#
# SQFT living : int64 --> float64
#
# Floor: float64 --> int64
#
# SQFT lot: int64 --> float64
#
# Year Built: float64 --> int64
#
# Year Renovated : float64 --> int64
#
# Zipcode: float64 --> int64
#
# SQFT living 15 : int64 --> flot64
#
# SQFT lot 15: int64 --> float64
#
#
#
#
#
#
#
# sales data:
#
# ID : int -->str
# Date: object --> datetime
#
# price: object --> float

# %% [markdown]
# ### Step 3: Detect Missing Values

# %%
######################### TO DO ##############################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
#checking for the missing values in the house-df  dataframe.

house_df.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Bedrooms             0
# Bathrooms            2
# SQFT living          0
# SQFT lot             2
# Floors               0
# Waterfront?          8
# View                 2
# House Condition      6
# Grade                2
# SQFT above           1
# SQFT basement        0
# Year Built           1
# Year Renovated     337
# Zipcode              3
# Lat                  1
# Long                 1
# SQFT living 15       0
# SQFT lot 15          0
# dtype: int64

# %%
#checking the missing values in the sale_df dataframe.

sales_df.isnull().sum()
# Out:
# Unnamed: 0    0
# Id            0
# DATE          0
# Price         4
# dtype: int64

# %% [markdown]
# Q: Which variables/columns have missing values?

# %% [markdown]
# A: ##### TO DO #####
#
#
#
# Missing values in house_df dataframe.
#
# Bathrooms --> 2
# SQFT lot --> 2
# Waterfront? --> 8
# View --> 2
# House Condition --> 6
# Grade --> 6
# SQFT above --> 1
# Year Built --> 1
# Year Renovated --> 337
# Zipcode --> 3
# Lat --> 1
# Long --> 1
#
#
#
# Missing values in sales_df dataframe.
#
# price --> 4

# %% [markdown]
# ### Step 4: Detect Outliers

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

#To detect outliers we have to import seaborn first

import seaborn as sns

# %%
#LETS DETECT THE OUTLIERS USING THE BOXPLOT METHOD.

# %%
sns.boxplot(data=house_df['Bedrooms'])
# Out:
# <AxesSubplot: >

# %%
house_df['Bedrooms'].describe()
# Out:
# count    21613.000000
# mean         3.372091
# std          0.947533
# min          0.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max         33.000000
# Name: Bedrooms, dtype: float64

# %%
sns.boxplot(data=house_df['Bathrooms'])
# Out:
# <AxesSubplot: >

# %%
house_df['Bathrooms'].describe()
# Out:
# count    21611.000000
# mean         2.115173
# std          0.772019
# min          0.000000
# 25%          1.750000
# 50%          2.250000
# 75%          2.500000
# max         10.000000
# Name: Bathrooms, dtype: float64

# %%
sns.boxplot(data=house_df['SQFT living'])
# Out:
# <AxesSubplot: >

# %%
house_df['SQFT living'].describe()
# Out:
# count    21613.000000
# mean      2079.899736
# std        918.440897
# min        290.000000
# 25%       1427.000000
# 50%       1910.000000
# 75%       2550.000000
# max      13540.000000
# Name: SQFT living, dtype: float64

# %%
sns.boxplot(data=house_df['SQFT lot'])
# Out:
# <AxesSubplot: >

# %%
house_df['SQFT lot'].describe()
# Out:
# count    2.161100e+04
# mean     1.510388e+04
# std      4.141929e+04
# min      5.200000e+02
# 25%      5.040000e+03
# 50%      7.618000e+03
# 75%      1.068750e+04
# max      1.651359e+06
# Name: SQFT lot, dtype: float64

# %%
sns.boxplot(data=house_df['Floors'])
# Out:
# <AxesSubplot: >

# %%
house_df['Floors'].describe()
# Out:
# count    21613.000000
# mean         1.494309
# std          0.539989
# min          1.000000
# 25%          1.000000
# 50%          1.500000
# 75%          2.000000
# max          3.500000
# Name: Floors, dtype: float64

# %%
sns.boxplot(data=house_df['Grade'])
# Out:
# <AxesSubplot: >

# %%
house_df['Grade'].describe()
# Out:
# count    21611.000000
# mean         7.656795
# std          1.175475
# min          1.000000
# 25%          7.000000
# 50%          7.000000
# 75%          8.000000
# max         13.000000
# Name: Grade, dtype: float64

# %%
sns.boxplot(data=house_df['SQFT above'])
# Out:
# <AxesSubplot: >

# %%
house_df['SQFT above'].describe()
# Out:
# count    21612.000000
# mean      1788.861281
# std        831.369379
# min        290.000000
# 25%       1190.000000
# 50%       1560.000000
# 75%       2210.000000
# max      12542.000000
# Name: SQFT above, dtype: float64

# %%
sns.boxplot(data=house_df['SQFT basement'])
# Out:
# <AxesSubplot: >

# %%
house_df['SQFT basement'].describe()
# Out:
# count    21613.000000
# mean       291.509045
# std        442.575043
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%        560.000000
# max       4820.000000
# Name: SQFT basement, dtype: float64

# %%
sns.boxplot(data=house_df['Year Built'])
# Out:
# <AxesSubplot: >

# %%
house_df['Year Built'].describe()
# Out:
# count    21612.000000
# mean      1970.958079
# std         30.108306
# min       1000.000000
# 25%       1951.000000
# 50%       1975.000000
# 75%       1997.000000
# max       2050.000000
# Name: Year Built, dtype: float64

# %%
sns.boxplot(data=house_df['Year Renovated'])
# Out:
# <AxesSubplot: >

# %%
house_df['Year Renovated'].describe()
# Out:
# count    21276.000000
# mean        85.645422
# std        404.495380
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       2015.000000
# Name: Year Renovated, dtype: float64

# %%
sns.boxplot(data=house_df['SQFT living 15'])
# Out:
# <AxesSubplot: >

# %%
house_df['SQFT living 15'].describe()
# Out:
# count    21613.000000
# mean      1986.552492
# std        685.391304
# min        399.000000
# 25%       1490.000000
# 50%       1840.000000
# 75%       2360.000000
# max       6210.000000
# Name: SQFT living 15, dtype: float64

# %%
sns.boxplot(data=house_df['SQFT lot 15'])
# Out:
# <AxesSubplot: >

# %%
house_df['SQFT lot 15'].describe()
# Out:
# count    2.161300e+04
# mean     1.343592e+04
# std      1.018656e+05
# min      6.510000e+02
# 25%      5.100000e+03
# 50%      7.620000e+03
# 75%      1.008300e+04
# max      1.444040e+07
# Name: SQFT lot 15, dtype: float64

# %% [markdown]
# Q: Which variables/columns have outliers?

# %% [markdown]
# A: ##### TO DO #####
#
# Except for the floor everything has outliers.
#
# Bedrooms
# Bathrooms
# Sqft living
# Sqft lot
# Grade
# SQFT above
# Sqft basement
# Year Built
# Year Renovated
# SQFT living 15
# SQFT lot 15

# %% [markdown]
# ### Step 5: Write Data Cleaning Plan

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# #### Data Cleaning Plan:
#
# ####### TO DO #######
#
#
# change  the datatype for the required variables.
#
# Treat all the outliers found above.
#
# Also treat the variables that has a missing values
#
# also drop any unwanted columns

# %% [markdown]
# ## Part 3: Execute Data Cleaning Plan Using DEFINE / CLEAN / TEST Approach

# %% [markdown]
# ### Step 1: Understand DEFINE / CLEAN / TEST Approach

# %% [markdown]
# Refer to project instructions for an explanation of this step. You can copy and past the template in the cell below to use in each step of Part 3 as you are treating the issues you found in the data.

# %%
## DEFINE ###

#Befor starting treating the columns we need to change all the column names to lower case.



### CLEAN ### 

#change the house_df and sales_df column names to  snake case.

#House_df:
    

house_df.rename(columns={'SQFT living':'SQFT_Living'},inplace=True)

house_df.rename(columns={'SQFT lot':'SQFT_Lot'},inplace=True)

house_df.rename(columns={'Waterfront?':'waterfront'},inplace=True)

house_df.rename(columns={'House Condition':'House_Condition'},inplace=True)

house_df.rename(columns={'SQFT above':'SQFT_Above'},inplace=True)

house_df.rename(columns={'SQFT basement':'SQFT_Basement'},inplace=True)

house_df.rename(columns={'Year Built':'Year_Built'},inplace=True)

house_df.rename(columns={'Year Renovated':'Year_Renovated'},inplace=True)

house_df.rename(columns={'Lat':'Latitude'},inplace=True)

house_df.rename(columns={'Long':'Longitude'},inplace=True)

house_df.rename(columns={'SQFT living 15':'SQFT_Living_15'},inplace=True)

house_df.rename(columns={'SQFT lot 15':'SQFT_Lot_15'},inplace=True)


#sales_df:
    

sales_df.rename(columns={'Id':'ID'},inplace=True)
    
    




### TEST ###
house_df.head()

sales_df.head()
# Out:
#    Unnamed: 0          ID             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %%
### DEFINE ###
# Changing  the  Data type for the mentioned variables above.


### CLEAN ### 

#house_df:

house_df.ID= house_df.ID.astype(str)

house_df.Bathrooms= house_df.Bathrooms.astype(int)

#house_df.Year_Renovated = house_df.Year_Renovated.astype(object)


house_df.Zipcode = house_df.Zipcode.astype(object)


house_df.SQFT_Living_15 = house_df.SQFT_Living_15.astype(object)

house_df.SQFT_Lot_15 = house_df.SQFT_Lot_15.astype(object)


house_df.waterfront = house_df.waterfront.astype(str)


house_df.View = house_df.View.astype(str)


house_df.House_Condition = house_df.House_Condition.astype(str)



## sales_df


sales_df.ID = sales_df.ID.astype(str)

#sales_df.DATE = pd.to_datetime(Sales_df['date'])




#sales_df.Price = sales_df.Price.astype(float)






### TEST ###

house_df.info()

sales_df.info()
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40228\3925736814.py in <module>
#       9 house_df.ID= house_df.ID.astype(str)
#      10
# ---> 11 house_df.Bathrooms= house_df.Bathrooms.astype(int)
#      12
#      13 #house_df.Year_Renovated = house_df.Year_Renovated.astype(object)
#
# ~\anaconda3\envs\data_cleaning\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# ~\anaconda3\envs\data_cleaning\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     448
# ...

# %% [markdown]
# ### Step 2: Treat Names / Casing / Spelling Issues

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
#Done with these steps above.

# %%
### DEFINE ###


### CLEAN ### 


### TEST ###

# %% [markdown]
# ### Step 3: Treat Missing Values

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########


#Fillin the missing values with mean.

# If there are toomany missing values then we can just drop them.

# %%
### DEFINE ###


#Fill in the missing values for:  Bathroom, sqft lot, waterfront,view,house condition, grade, sqft above, year built, zipcode,latitude,longitude.
#Drop the year renovated column as it is haviny too many missing values.



### CLEAN ### 

#house_df

#house_df.Bathrooms = house_df.Bathrooms.fillna(house_df.Bathrooms.mean())

#house_df.SQFT_Lot= house_df.SQFT_Lot.fillna(house_df.SQFT_Lot.mean())

#house_df.waterfront = house_df.waterfront.fillna(house_df.waterfront.mean())

#house_df.View = house_df.View.fillna(house_df.View.mean())

#house_df.House_Condition = house_df.House_Condition.fillna(house_df.House_Condition.mean())

house_df.Grade = house_df.Grade.fillna(house_df.Grade.mean())

house_df.SQFT_Above = house_df.SQFT_Above.fillna(house_df.SQFT_Above.mean())

house_df.Year_Built = house_df.Year_Built.fillna(house_df.Year_Built.mean())

house_df.Zipcode= house_df.Zipcode.fillna(house_df.Zipcode.mean())

house_df.Latitude= house_df.Latitude.fillna(house_df.Latitude.mean())

house_df.Longitude = house_df.Longitude.fillna(house_df.Longitude.mean())
#
#sale_df:
#sales_df.Price = sales_df.Price.fillna(sales_df.Price.mean())



### TEST ###

#house_df.Bathrooms.isnull().sum()

#house_df.SQFT_Lot.isnull().sum()

#house_df.waterfront.isnull().sum()

#house_df.View.isnull().sum()

#house_df.House_Condition.isnull().sum()

house_df.Grade.isnull().sum()

house_df.SQFT_Above.isnull().sum()

house_df.Year_Built.isnull().sum()

house_df.Zipcode.isnull().sum()

house_df.Latitude.isnull().sum()

house_df.Longitude.isnull().sum()






#sales_df.Price.isnull().sum()
# Out:
# 0

# %% [markdown]
# # Dropping the unwanted columns:

# %%
house_df.head(100)
# Out:
#     Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT_Living  SQFT_Lot  \
# 0            0  7129300520         3       1.00         1180    5650.0
# 1            1  6414100192         3       2.25         2570    7242.0
# 2            2  5631500400         2       1.00          770   10000.0
# 3            3  2487200875         4       3.00         1960    5000.0
# 4            4  1954400510         3       2.00         1680    8080.0
# ..         ...         ...       ...        ...          ...       ...
# 95          95  1483300570         4       2.50         3300   10250.0
# 96          96  3422049190         3       1.75         1960   15681.0
# 97          97  1099611230         4       1.50         1160    6400.0
# 98          98   722079104         3       1.75         1810   41800.0
# 99          99  7338200240         3       2.50         2320   36847.0
#
#     Floors waterfront       View  House_Condition  Grade  SQFT_Above  \
# ...

# %%
#dropping the unnamed:0 column from house_df

# Also drop the unnamed:0 from sales_df.

# %%
house_df = house_df.drop('Unnamed: 0', axis=1)

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               21613 non-null  object
#  1   Bedrooms         21613 non-null  int64
#  2   Bathrooms        21611 non-null  float64
#  3   SQFT_Living      21613 non-null  int64
#  4   SQFT_Lot         21611 non-null  float64
#  5   Floors           21613 non-null  float64
#  6   waterfront       21605 non-null  object
#  7   View             21611 non-null  object
#  8   House_Condition  21607 non-null  object
#  9   Grade            21613 non-null  float64
#  10  SQFT_Above       21613 non-null  float64
#  11  SQFT_Basement    21613 non-null  int64
#  12  Year_Built       21613 non-null  float64
#  13  Year_Renovated   21276 non-null  float64
#  14  Zipcode          21613 non-null  float64
#  15  Latitude         21613 non-null  float64
# ...

# %%
sales_df = sales_df.drop('Unnamed: 0', axis=1)

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      21613 non-null  int64
#  1   DATE    21613 non-null  object
#  2   Price   21609 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 506.7+ KB

# %%
house_df.isnull().sum()
# Out:
# ID                   0
# Bedrooms             0
# Bathrooms            2
# SQFT_Living          0
# SQFT_Lot             2
# Floors               0
# waterfront           8
# View                 2
# House_Condition      6
# Grade                0
# SQFT_Above           0
# SQFT_Basement        0
# Year_Built           0
# Year_Renovated     337
# Zipcode              0
# Latitude             0
# Longitude            0
# SQFT_Living_15       0
# SQFT_Lot_15          0
# dtype: int64

# %%
# Drop Year Renovated as it has too mnay missing values.

house_df = house_df.drop('Year_Renovated', axis=1)

# %%
# Still we have waterfront, view and House condition that has some missing values.Recheck them
#Try to fill in the missing values with mean.

# %%
house_df.View = house_df.View.fillna(house_df.View.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40228\4144541178.py in <module>
# ----> 1 house_df.View = house_df.View.fillna(house_df.View.mean())
#
# ~\anaconda3\envs\data_cleaning\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11845             **kwargs,
#   11846         ):
# > 11847             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11848
#   11849         setattr(cls, "mean", mean)
#
# ~\anaconda3\envs\data_cleaning\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11399         **kwargs,
#   11400     ) -> Series | float:
# > 11401         return self._stat_function(
#   11402             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   11403         )
#
# ...

# %%
house_df.waterfront = house_df.waterfront.fillna(house_df.View.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40228\1750887461.py in <module>
# ----> 1 house_df.waterfront = house_df.waterfront.fillna(house_df.View.mean())
#
# ~\anaconda3\envs\data_cleaning\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11845             **kwargs,
#   11846         ):
# > 11847             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11848
#   11849         setattr(cls, "mean", mean)
#
# ~\anaconda3\envs\data_cleaning\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11399         **kwargs,
#   11400     ) -> Series | float:
# > 11401         return self._stat_function(
#   11402             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   11403         )
#
# ...

# %%
house_df.House_Condition = house_df.House_Condition.fillna(house_df.View.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40228\1057819874.py in <module>
# ----> 1 house_df.House_Condition = house_df.House_Condition.fillna(house_df.View.mean())
#
# ~\anaconda3\envs\data_cleaning\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11845             **kwargs,
#   11846         ):
# > 11847             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11848
#   11849         setattr(cls, "mean", mean)
#
# ~\anaconda3\envs\data_cleaning\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11399         **kwargs,
#   11400     ) -> Series | float:
# > 11401         return self._stat_function(
#   11402             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
# ...

# %% [markdown]
# ### Step 4: Treat Outliers

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
# import zscore

from scipy.stats import zscore

# %%
### DEFINE ###


### CLEAN ### 
house_df['Bedrooms_zscore'] = zscore(house_df['Bedrooms'])

#house_df['Bathrooms_zscore'] = zscore(house_df['Bathrooms'])

#house_df['SQFT_Living_zscore'] = zscore(house_df['SQFT_Living'])

#house_df['SQFT_Lot_zscore'] = zscore(house_df['SQFT_Lot'])

#house_df['Grade_zscore'] = zscore(house_df['Grade'])

#house_df['SQFT_Above_zscore'] = zscore(house_df['SQFT_Above'])

#house_df['SQFT_Basement_zscore'] = zscore(house_df['SQFT_Basement'])

#house_df['Year_Built_zscore'] = zscore(house_df['Year_Built'])

#house_df['Year_Renovated_zscore'] = zscore(house_df['Year_Renovated'])

#house_df['SQFT_Living_15_zscore'] = zscore(house_df['SQFT_Living_15'])

#house_df['SQFT_Lot_15_zscore'] = zscore(house_df['SQFT_Lot_15_zscore'])


### TEST ###
house_df.query('Bedrooms_zscore >  3 and Bedrooms_zscore < -3')

house_df.query('Bathrooms_zscore >  3 and Bathrooms_zscore < -3')

house_df.query('SQFT_Living_zscore >  3 and SQFT_Living_zscore < -3')

house_df.query('Grade_zscore >  3 and Grade_zscore < -3')

house_df.query('SQFT_Above_zscore >  3 and SQFT_Above_zscore < -3')

#house_df.query('SQFT_Basement_zscore >  3 and SQFT_Basement_zscore < -3')

#house_df.query('Year_Built_zscore >  3 and Year_Built_zscore < -3')

#house_df.query('Year_Renovated_zscore >  3 and Year_Renovated_zscore < -3')

#house_df.query('SQFT_Living_15_zscore >  3 and SQFT_Living_15_zscore < -3')

#house_df.query('SQFT_Lot_15_zscore >  3 and SQFT_Lot_15_zscore < -3')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\data_cleaning\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     197             if self.has_resolvers:
# --> 198                 return self.resolvers[key]
#     199
#
# ~\anaconda3\envs\data_cleaning\lib\collections\__init__.py in __getitem__(self, key)
#     940                 pass
# --> 941         return self.__missing__(key)            # support subclasses that define __missing__
#     942
#
# ~\anaconda3\envs\data_cleaning\lib\collections\__init__.py in __missing__(self, key)
#     932     def __missing__(self, key):
# --> 933         raise KeyError(key)
#     934
#
# KeyError: 'Bathrooms_zscore'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ### Step 5: Summarize Actions Taken & Justify Approach

# %% [raw]
# ######################### TO DO ###################################
#
# ####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# ####### TO DO ###### - Edit this cell to add your summary and justification per project instructions.
#
#
# 1.changed the datatyes of some columns to their appropriate datatype.Becuse wrong dataype can give incossistancies and errors in the results.
#
# 2.changes the names of some columns and took out spaces between them by chenging them to snake_cases.
#
# 3.Found some columns with missing data and tried to fill in with mean wherever required.and drop the columns if there are many missing values.
#
# 4.Dropped some unused column wherever i thought was necessary.

# %% [markdown]
# ## Part 4: Re-Express Categorical Variables

# %% [markdown]
# ### Step 1: Determine Which Variables Need to Be Re-Expressed

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
house_df.head()
# Out:
#            ID  Bedrooms  Bathrooms  SQFT_Living  SQFT_Lot  Floors waterfront  \
# 0  7129300520         3       1.00         1180    5650.0     1.0         No
# 1  6414100192         3       2.25         2570    7242.0     2.0         No
# 2  5631500400         2       1.00          770   10000.0     1.0         No
# 3  2487200875         4       3.00         1960    5000.0     1.0         No
# 4  1954400510         3       2.00         1680    8080.0     1.0         No
#
#         View  House_Condition  Grade  SQFT_Above  SQFT_Basement  Year_Built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
# ...

# %% [markdown]
# List categorical variables which need to be re-expressed here:
#
# - ########## TO DO ###########
# - ########## TO DO ###########
# - ########## TO DO ###########
# - ########## TO DO ########### ........
#
# Waterfront
#
# View
#
# House_condition

# %% [markdown]
# ### Step 2: Choose Method to Re-Express Variables

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to explain which method you are choosing to re-express each variable and why.
#
# Waterfront: we can use the method to change yes and no with 1  and 0 respectively.
#
# View: We can use replace with weighted integers.
#
# House_COndition: We can use replace with weighted integers.

# %% [markdown]
# ### Step 3: Perform Transformation

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
import pandas as pd

import numpy as np

# %% [markdown]
# #  waterfront

# %%
house_df.waterfront.unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
house_df['waterfront'] = house_df['waterfront'].replace({'Yes':1, "No":0})

# %%
house_df.head()
# Out:
#            ID  Bedrooms  Bathrooms  SQFT_Living  SQFT_Lot  Floors  waterfront  \
# 0  7129300520         3       1.00         1180    5650.0     1.0         0.0
# 1  6414100192         3       2.25         2570    7242.0     2.0         0.0
# 2  5631500400         2       1.00          770   10000.0     1.0         0.0
# 3  2487200875         4       3.00         1960    5000.0     1.0         0.0
# 4  1954400510         3       2.00         1680    8080.0     1.0         0.0
#
#         View  House_Condition  Grade  SQFT_Above  SQFT_Basement  Year_Built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
# ...

# %% [markdown]
# # View

# %%
house_df.View.unique()
# Out:
# array(['Very Poor', 'Good', 'Great', 'Neutral', nan, 'Poor'], dtype=object)

# %%
house_df.View = house_df.View.replace({'Very Poor':1,'Good':4, 'Great':5, 'Neutral':3, 'Poor':2})

# %%
house_df.View.unique()
# Out:
# array([ 1.,  4.,  5.,  3., nan,  2.])

# %% [markdown]
# # House Condition

# %%
house_df.House_Condition.unique()
# Out:
# array(['OK Condition', 'Great Condition', 'Good Condition',
#        'Very Bad Condition', 'Bad Condition', nan], dtype=object)

# %%
house_df.House_Condition = house_df.House_Condition.replace({'OK Condition':1,'Great Condition':4, 'Good Condition':5, 'Very Bad Condition':3, 'Bad Condition':2})

# %%
house_df.House_Condition.unique()
# Out:
# array([ 1.,  4.,  5.,  3.,  2., nan])

# %% [markdown]
# ### Step 4: Summarize Actions Taken & Justify Approach

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to add your summary and justification per project instructions.
#
# Edit this cell to explain which method you are choosing to re-express each variable and why.
#
# Waterfront: we can use the method to change yes and no with 1 and 0 respectively.
#
# View: We can use replace with weighted integers.
#
# House_COndition: We can use replace with weighted integers.

# %% [markdown]
# ## Part 5: Combine Datasets into Master DataFrame

# %% [markdown]
# ### Step 1: Choose Method to Merge DataFrames into New Master DataFrame

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to explain which method you are choosing to merge the data and why.
#
# Lets choose the.merge method to merge different dataframes .This looks smimpler than other.

# %% [markdown]
# ### Step 2: Merge DataFrames

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
house_df.head()
sales_df.head()
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %%
#merge the two dataframes: house_df and sales_df on a column id.




new_df = sales_df.merge(house_df, on='ID')

# %%
# Use .head() method to print first few rows of new master dataframe
new_df.head(50)
# Out:
#             ID             DATE          Price  Bedrooms  Bathrooms  \
# 0   7129300520  20141013T000000    $221,900.00         3          1
# 1   6414100192  20141209T000000    $538,000.00         3          2
# 2   5631500400  20150225T000000    $180,000.00         2          1
# 3   2487200875  20141209T000000    $604,000.00         4          3
# 4   1954400510  20150218T000000    $510,000.00         3          2
# 5   7237550310  20140512T000000  $1,225,000.00         4          4
# 6   1321400060  20140627T000000    $257,500.00         3          2
# 7   2008000270  20150115T000000    $291,850.00         3          1
# 8   2414600126  20150415T000000    $229,500.00         3          1
# 9   3793500160  20150312T000000    $323,000.00         3          2
# 10  1736800520  20150403T000000    $662,500.00         3          2
# 11  9212900260  20140527T000000    $468,000.00         2          1
# 12   114101516  20140528T000000    $310,000.00         3          1
# ...

# %% [markdown]
# ### Step 3: Save Master DataFrame to New .CSV

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

new_df.to_csv('new.csv', index=False)

# %% [markdown]
# ### Step 4: Push to GitHub / Share Link with Tech Lead & SME

# %% [markdown]
# ##### This step will be completed outside of Jupyter Notebook. See "Submitting Project" Video Walkthrough from Unit 1 if you have any questions.

# %% [markdown]
# ### Step 5: Record Brief Code Walkthrough / Share Link with Tech Lead & SME

# %% [markdown]
# ##### This step will be completed outside of Jupyter Notebook. See "Submitting Project" Video Walkthrough from Unit 1 if you have any questions.
